# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when, avg, count, abs as spark_abs
import time
spark = SparkSession.builder \
    .appName("CIRT Analysis") \
    .config("spark.driver.memory", "4g") \
    .getOrCreate()

df = spark.read.parquet("/opt/airflow/data/final/merged_data.parquet")

print(f"Total rows: {df.count():,}")
print(f"Total columns: {len(df.columns)}")

# Some basic analysis
df.select("Borrower Credit Score at Origination", "vs4_trimerge").describe().show()
# Out:
# Total rows: 1,295,846
# Total columns: 117
# +-------+------------------------------------+------------------+
# |summary|Borrower Credit Score at Origination|      vs4_trimerge|
# +-------+------------------------------------+------------------+
# |  count|                             1295219|           1295846|
# |   mean|                   751.9691835898022| 762.4120080626865|
# | stddev|                   42.41599431136098|45.863278799638096|
# |    min|                                 580|               485|
# |    max|                                 840|               850|
# +-------+------------------------------------+------------------+

# %%
import pandas as pd
pd.read_parquet("/opt/airflow/data/final/merged_data.parquet").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1295846 entries, 0 to 1295845
# Columns: 117 entries, Reference Pool ID to vs4_bimerge_highest
# dtypes: float64(53), int32(17), object(47)
# memory usage: 1.0+ GB

# %%
start = time.time()

df_unoptimized = df \
    .withColumn("score_diff", col("vs4_trimerge") - col("Borrower Credit Score at Origination")) \
    .withColumn("is_delinquent", when(col("Current Loan Delinquency Status") > 0, 1).otherwise(0))

df_unoptimized = df_unoptimized.filter(
    (col("Borrower Credit Score at Origination").between(300, 850)) &
    (col("vs4_trimerge").between(300, 850))
)

count_unoptimized = df_unoptimized.count()
time_unoptimized = time.time() - start
print(f"Rows: {count_unoptimized:,}")
print(f"Time: {time_unoptimized:.2f}s")
# Out:
# Rows: 1,295,219
# Time: 0.20s

# %%
start = time.time()
df_optimized = df.filter(
    (col("Borrower Credit Score at Origination").between(300, 850)) &
    (col("vs4_trimerge").between(300, 850)) &
    (col("Current Loan Delinquency Status").isNotNull())
)

df_optimized = df_optimized \
    .withColumn("score_diff", col("vs4_trimerge") - col("Borrower Credit Score at Origination")) \
    .withColumn("is_delinquent", when(col("Current Loan Delinquency Status") > 0, 1).otherwise(0))

count_optimized = df_optimized.count()
time_optimized = time.time() - start

print(f"Rows: {count_optimized:,}")
print(f"Time: {time_optimized:.2f}s")

speedup = time_unoptimized / time_optimized
print(f"\n Speedup: {speedup:.2f}x faster")
# Out:
# Rows: 1,115,619
# Time: 0.18s
#
#  Speedup: 1.09x faster

# %%
delinq_analysis = df_optimized.groupBy("is_delinquent") \
    .agg(
        count("*").alias("total_loans"),
        avg("Borrower Credit Score at Origination").alias("avg_fico"),
        avg("vs4_trimerge").alias("avg_vs4"),
        avg(spark_abs("score_diff")).alias("avg_score_diff")
    )
delinq_analysis.explain(mode="formatted")
print("\nDelinquency Comparison:")
delinq_analysis.show()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (7)
# +- HashAggregate (6)
#    +- Exchange (5)
#       +- HashAggregate (4)
#          +- Project (3)
#             +- Filter (2)
#                +- Scan parquet  (1)
#
#
# (1) Scan parquet
# Output [3]: [Borrower Credit Score at Origination#4507, Current Loan Delinquency Status#4523, vs4_trimerge#4597]
# Batched: true
# Location: InMemoryFileIndex [file:/opt/airflow/data/final/merged_data.parquet]
# PushedFilters: [IsNotNull(`Borrower Credit Score at Origination`), IsNotNull(vs4_trimerge), GreaterThanOrEqual(`Borrower Credit Score at Origination`,300), LessThanOrEqual(`Borrower Credit Score at Origination`,850), GreaterThanOrEqual(vs4_trimerge,300), LessThanOrEqual(vs4_trimerge,850), IsNotNull(`Current Loan Delinquency Status`)]
# ReadSchema: struct<Borrower Credit Score at Origination:int,Current Loan Delinquency Status:int,vs4_trimerge:int>
#
# (2) Filter
# Input [3]: [Borrower Credit Score at Origination#4507, Current Loan Delinquency Status#4523, vs4_trimerge#4597]
# Condition : ((((((isnotnull(Borrower Credit Score at Origination#4507) AND isnotnull(vs4_trimerge#4597)) AND (Borrower Credit Score at Origination#4507 >= 300)) AND (Borrower Credit Score at Origination#4507 <= 850)) AND (vs4_trimerge#4597 >= 300)) AND (vs4_trimerge#4597 <= 850)) AND isnotnull(Current Loan Delinquency Status#4523))
#
# (3) Project
# Output [4]: [Borrower Credit Score at Origination#4507, vs4_trimerge#4597, (vs4_trimerge#4597 - Borrower Credit Score at Origination#4507) AS score_diff#6863, CASE WHEN (Current Loan Delinquency Status#4523 > 0) THEN 1 ELSE 0 END AS is_delinquent#6982]
# Input [3]: [Borrower Credit Score at Origination#4507, Current Loan Delinquency Status#4523, vs4_trimerge#4597]
#
# (4) HashAggregate
# Input [4]: [Borrower Credit Score at Origination#4507, vs4_trimerge#4597, score_diff#6863, is_delinquent#6982]
# Keys [1]: [is_delinquent#6982]
# Functions [4]: [partial_count(1), partial_avg(Borrower Credit Score at Origination#4507), partial_avg(vs4_trimerge#4597), partial_avg(abs(score_diff#6863))]
# Aggregate Attributes [7]: [count#7835L, sum#7836, count#7837L, sum#7838, count#7839L, sum#7840, count#7841L]
# Results [8]: [is_delinquent#6982, count#7842L, sum#7843, count#7844L, sum#7845, count#7846L, sum#7847, count#7848L]
#
# (5) Exchange
# Input [8]: [is_delinquent#6982, count#7842L, sum#7843, count#7844L, sum#7845, count#7846L, sum#7847, count#7848L]
# Arguments: hashpartitioning(is_delinquent#6982, 200), ENSURE_REQUIREMENTS, [plan_id=1411]
#
# (6) HashAggregate
# Input [8]: [is_delinquent#6982, count#7842L, sum#7843, count#7844L, sum#7845, count#7846L, sum#7847, count#7848L]
# Keys [1]: [is_delinquent#6982]
# Functions [4]: [count(1), avg(Borrower Credit Score at Origination#4507), avg(vs4_trimerge#4597), avg(abs(score_diff#6863))]
# Aggregate Attributes [4]: [count(1)#7822L, avg(Borrower Credit Score at Origination#4507)#7824, avg(vs4_trimerge#4597)#7826, avg(abs(score_diff#6863))#7828]
# Results [5]: [is_delinquent#6982, count(1)#7822L AS total_loans#7823L, avg(Borrower Credit Score at Origination#4507)#7824 AS avg_fico#7825, avg(vs4_trimerge#4597)#7826 AS avg_vs4#7827, avg(abs(score_diff#6863))#7828 AS avg_score_diff#7829]
#
# (7) AdaptiveSparkPlan
# Output [5]: [is_delinquent#6982, total_loans#7823L, avg_fico#7825, avg_vs4#7827, avg_score_diff#7829]
# Arguments: isFinalPlan=false
#
#
#
# Delinquency Comparison:
# +-------------+-----------+-----------------+-----------------+------------------+
# |is_delinquent|total_loans|         avg_fico|          avg_vs4|    avg_score_diff|
# +-------------+-----------+-----------------+-----------------+------------------+
# |            1|      22579|715.5991407945436|721.5006421896452| 30.69701935426724|
# |            0|    1093040| 753.449515113811| 764.111691246432|27.557464502671447|
# +-------------+-----------+-----------------+-----------------+------------------+

# %%
df_optimized.createOrReplaceTempView("loans")

#SQL Query 1 - Delinquency by Score Range
query1 = """
SELECT 
    CASE 
        WHEN vs4_trimerge >= 700 THEN 'High'
        WHEN vs4_trimerge >= 600 THEN 'Medium'
        ELSE 'Low'
    END as score_range,
    COUNT(*) as loans,
    ROUND(AVG(is_delinquent) * 100, 2) as delinq_rate
FROM loans
GROUP BY 
    CASE 
        WHEN vs4_trimerge >= 700 THEN 'High'
        WHEN vs4_trimerge >= 600 THEN 'Medium'
        ELSE 'Low'
    END
ORDER BY delinq_rate
"""
spark.sql(query1).explain(mode="formatted")
spark.sql(query1).show()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (9)
# +- Sort (8)
#    +- Exchange (7)
#       +- HashAggregate (6)
#          +- Exchange (5)
#             +- HashAggregate (4)
#                +- Project (3)
#                   +- Filter (2)
#                      +- Scan parquet  (1)
#
#
# (1) Scan parquet
# Output [3]: [Borrower Credit Score at Origination#4507, Current Loan Delinquency Status#4523, vs4_trimerge#4597]
# Batched: true
# Location: InMemoryFileIndex [file:/opt/airflow/data/final/merged_data.parquet]
# PushedFilters: [IsNotNull(`Borrower Credit Score at Origination`), IsNotNull(vs4_trimerge), GreaterThanOrEqual(`Borrower Credit Score at Origination`,300), LessThanOrEqual(`Borrower Credit Score at Origination`,850), GreaterThanOrEqual(vs4_trimerge,300), LessThanOrEqual(vs4_trimerge,850), IsNotNull(`Current Loan Delinquency Status`)]
# ReadSchema: struct<Borrower Credit Score at Origination:int,Current Loan Delinquency Status:int,vs4_trimerge:int>
#
# (2) Filter
# Input [3]: [Borrower Credit Score at Origination#4507, Current Loan Delinquency Status#4523, vs4_trimerge#4597]
# Condition : ((((((isnotnull(Borrower Credit Score at Origination#4507) AND isnotnull(vs4_trimerge#4597)) AND (Borrower Credit Score at Origination#4507 >= 300)) AND (Borrower Credit Score at Origination#4507 <= 850)) AND (vs4_trimerge#4597 >= 300)) AND (vs4_trimerge#4597 <= 850)) AND isnotnull(Current Loan Delinquency Status#4523))
#
# (3) Project
# Output [2]: [CASE WHEN (Current Loan Delinquency Status#4523 > 0) THEN 1 ELSE 0 END AS is_delinquent#6982, CASE WHEN (vs4_trimerge#4597 >= 700) THEN High WHEN (vs4_trimerge#4597 >= 600) THEN Medium ELSE Low END AS _groupingexpression#7890]
# Input [3]: [Borrower Credit Score at Origination#4507, Current Loan Delinquency Status#4523, vs4_trimerge#4597]
#
# (4) HashAggregate
# Input [2]: [is_delinquent#6982, _groupingexpression#7890]
# Keys [1]: [_groupingexpression#7890]
# Functions [2]: [partial_count(1), partial_avg(is_delinquent#6982)]
# Aggregate Attributes [3]: [count#7891L, sum#7892, count#7893L]
# Results [4]: [_groupingexpression#7890, count#7894L, sum#7895, count#7896L]
#
# (5) Exchange
# Input [4]: [_groupingexpression#7890, count#7894L, sum#7895, count#7896L]
# Arguments: hashpartitioning(_groupingexpression#7890, 200), ENSURE_REQUIREMENTS, [plan_id=1497]
#
# (6) HashAggregate
# Input [4]: [_groupingexpression#7890, count#7894L, sum#7895, count#7896L]
# Keys [1]: [_groupingexpression#7890]
# Functions [2]: [count(1), avg(is_delinquent#6982)]
# Aggregate Attributes [2]: [count(1)#7885L, avg(is_delinquent#6982)#7886]
# Results [3]: [_groupingexpression#7890 AS score_range#7882, count(1)#7885L AS loans#7883L, round((avg(is_delinquent#6982)#7886 * 100.0), 2) AS delinq_rate#7884]
#
# (7) Exchange
# Input [3]: [score_range#7882, loans#7883L, delinq_rate#7884]
# Arguments: rangepartitioning(delinq_rate#7884 ASC NULLS FIRST, 200), ENSURE_REQUIREMENTS, [plan_id=1500]
#
# (8) Sort
# Input [3]: [score_range#7882, loans#7883L, delinq_rate#7884]
# Arguments: [delinq_rate#7884 ASC NULLS FIRST], true, 0
#
# (9) AdaptiveSparkPlan
# Output [3]: [score_range#7882, loans#7883L, delinq_rate#7884]
# Arguments: isFinalPlan=false
#
#
# +-----------+-------+-----------+
# |score_range|  loans|delinq_rate|
# +-----------+-------+-----------+
# |       High|1006496|       1.53|
# |     Medium| 108130|       6.51|
# |        Low|    993|      10.37|
# +-----------+-------+-----------+

# %%
# SQL Query 2 - VS4 vs FICO Comparison:
query2 = """
SELECT 
    CASE WHEN score_diff > 0 THEN 'VS4 Higher' ELSE 'FICO Higher' END as winner,
    COUNT(*) as loans,
    ROUND(AVG(score_diff), 2) as avg_diff,
    ROUND(AVG(is_delinquent) * 100, 2) as delinq_rate
FROM loans
GROUP BY CASE WHEN score_diff > 0 THEN 'VS4 Higher' ELSE 'FICO Higher' END
"""
query2_df = spark.sql(query2)
query2_df.show()
# Out:
# +-----------+------+--------+-----------+
# |     winner| loans|avg_diff|delinq_rate|
# +-----------+------+--------+-----------+
# | VS4 Higher|701121|   30.38|       1.82|
# |FICO Higher|414498|  -22.95|       2.37|
# +-----------+------+--------+-----------+

# %%
output_path = "/opt/airflow/data/final/fico_vs_vs4_analysis.parquet"

df_optimized.select(
    "Borrower Credit Score at Origination",
    "vs4_trimerge",
    "score_diff",
    "is_delinquent"
).write \
    .mode("overwrite") \
    .partitionBy("is_delinquent") \
    .parquet(output_path)
